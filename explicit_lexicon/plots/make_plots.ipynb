# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib as mpl
from matplotlib.pyplot import cm
import warnings
warnings.filterwarnings("ignore")
from plot_functions import *
import pickle
# %matplotlib inline

# %% [markdown]
# ## Rewards

# %%
boxplot_rewards()
plt.gca().text(-0.25, 1.2, 'A', transform=plt.gca().transAxes, 
         fontsize=25, fontweight='bold', va='top', ha='right')
plt.show()

# %% [markdown]
# ## ME indices

# %%
boxplot_ME_indices_bw(title=True)
plt.gca().text(-0.14, 1.2, 'B', transform=plt.gca().transAxes, 
         fontsize=25, fontweight='bold', va='top', ha='right')
plt.show()

# %% [markdown]
# ## Learning success

# %%
plot_learning_success('fixed')

# %%
plot_learning_success('dynamic')

# %% [markdown]
# ## Reward and ME bias for interval size k=15

# %%
plot_multiple_iter_k15()

# %% [markdown]
# ## Reward and ME bias for different exposure intervals

# %%
plot_multiple_iter(interval=[3,6,9,12,15], lexicon_type='fixed', mode='index')

# %%
plot_multiple_iter(interval=[3,6,9,12,15], lexicon_type='dynamic', mode='index')

# %% [markdown]
# ## Policies for optimal and suboptimal learning

# %%
plot_general_context_policies()

# %%
plot_specific_context_policies()

# %% [markdown]
# ## Ablation test

# %%
plot_multiple_iter_k15(ablation=True)

# %%
plot_multiple_iter_k15(ablation=True)
